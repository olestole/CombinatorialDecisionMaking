# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as patches

# %%
def read_output(filename):
    arr = []
    with open(filename) as f:
        for line in f:
            elm = line.strip().split(' ')
            int_elm = [int(elm) for elm in elm]
            arr.append(int_elm)
    return arr

# %%
def visualize_output(output):
    w = output[0][0]
    l = output[0][1]
    n = output[1][0]

    colors = np.array(['red', 'green', 'blue', 'yellow', 'orange', 'pink', 'purple', 'brown']*(round(n/8)))

    fig = plt.figure(figsize=(w/2, l/2))
    ax = fig.gca()
    ax.set_xticks(np.arange(0, w+1, 1))
    ax.set_yticks(np.arange(0, l+1, 1))
    plt.grid()
    for i, [width, height, x, y] in enumerate(np.array(output[2:])):
        rect = patches.Rectangle((x, y), width, height, linewidth=3, edgecolor='black', facecolor=colors[i])
        ax.add_patch(rect)
    plt.show()
    return fig

# %%
import os

filename = 'sol_ins-40.txt'
file_path = os.path.join("cp_solutions", filename)

output = read_output(file_path)
f = visualize_output(output)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /var/folders/vn/xw7vy4yj4p59wc8lpy7gnh200000gn/T/ipykernel_87747/3329127800.py in <module>
#       5
#       6 output = read_output(file_path)
# ----> 7 f = visualize_output(output)
#
# /var/folders/vn/xw7vy4yj4p59wc8lpy7gnh200000gn/T/ipykernel_87747/3184297098.py in visualize_output(output)
#      12     plt.grid()
#      13     for i, [width, height, x, y] in enumerate(np.array(output[2:])):
# ---> 14         rect = patches.Rectangle((x, y), width, height, linewidth=3, edgecolor='black', facecolor=colors[i])
#      15         ax.add_patch(rect)
#      16     plt.show()
#
# IndexError: index 72 is out of bounds for axis 0 with size 72
